# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, Eq, solve

# %%
from numpy import random

# %%
def G_val(x,y):
    xi = [0, 0, 1, 1]
    yi = [0, 1, 0, 1]
    G = 0
    for i in range(0, 4):
        
        d = (((x - xi[i])**2) + ((y - yi[i])**2))**0.5
        k = 1 / (1 + d)
        s=331 #speed of sound
        g = (s * 1) - d
        G += k * (g**2)
    return G 
#G_val(0.5,0.5)
def G_equation(x,y):
    xi = [0, 0, 1, 1]
    yi = [0, 1, 0, 1]
    G = 0
    for i in range(0, 4):
        
        d = (((x - xi[i])**2) + ((y - yi[i])**2))**0.5
        k = 1 / (1 + d)
        g = (331 * 10**-8) - d
        G += k * (g**2)
    # Normal distribution with mean 0 and variance 10^-3
    noise=random.normal(loc=0, scale=0.001, size=(1, 1))[0][0]
    return G-G_val(0.5,0.5)+noise
def objective_function(coords):
    return G_equation(coords[0], coords[1])
initial_guess = [0.5, 0.5]

# Minimize the objective function
result = minimize(objective_function, initial_guess, method='Nelder-Mead')
print("Minimum value:", result.fun)
print("Optimal coordinates (x, y):", result.x)


x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
x, y = np.meshgrid(x, y)

# Calculate the values of the equation for each point in the meshgrid
z = G_equation(x, y)

# Plot the 3D surface plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis')

# Show the plot
plt.show()
# Out:
# Minimum value: -255620.55677667522
# Optimal coordinates (x, y): [0.50633008 0.50621828]

# %%
G_equation(0.12,0.14)
# Out:
# 1493.8388484279458

# %% [markdown]
# if we are considering time =1 then coordinated are coming for minimum point x=60,y= 325
# otherwise
